# %%
import nltk

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
nltk.download('subjectivity')
nltk.download('movie_reviews')

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package subjectivity to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\subjectivity.zip.
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\movie_reviews.zip.

# %%
sia.polarity_scores('I am a human')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sia.polarity_scores('Horrible!')
# Out:
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5848}

# %%
sia.polarity_scores('This company has done increadibility well over the past year')
# Out:
# {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.2732}

# %%
sia.polarity_scores('This movie is increadible!')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# The economy has never been so good!
# The economy has never been good!
